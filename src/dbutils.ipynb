# %%
dbutils.fs.help()

# %%
dbutils.help()

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
# %sql
SHOW VOLUMES IN workspace.default;

# %%
# %sql
CREATE VOLUME workspace.default.demo_volume;

# %%
dbutils.fs.ls("/Volumes/workspace/default/demo_volume")

# %%
dbutils.fs.put("/Volumes/workspace/default/demo_volume/demo.txt","Hello Spark")

# %%
dbutils.fs.ls("/Volumes/workspace/default/demo_volume")

# %%
dbutils.widgets.text("username", "guest", "Enter Username")

# %%
dbutils.widgets.get("username")

# %%
dbutils.widgets.dropdown("state", "TN", ["TN","KA","AP"], "Select State")

# %%
dbutils.widgets.combobox("city", "Chennai", ["Chennai","Bangalore","Hyderabad"], "Select City")

# %%
dbutils.widgets.get("city")

# %%
dbutils.widgets.multiselect("courses", "Python", ["Python","SQL","Spark","Scala"], "Select Courses")

# %%
dbutils.widgets.get("courses")
