# %% [markdown]
# 10.1.1 UPLOAD FILES

# %%
df = spark.read.csv("/Volumes/workspace/default/demo_volume/sales.csv", header=True, inferSchema=True)

display(df)

# %%
df.write.format("delta").save("/Volumes/workspace/default/demo_volume/sales_delta")

# %% [markdown]
# 10.1.3  standard connector

# %%
df = spark.read.format("jdbc") \
.option("url", "jdbc:mysql://crossover.proxy.rlwy.net:27856/railway?useSSL=false&allowPublicKeyRetrieval=true") \
.option("dbtable", "customer") \
.option("user", "root") \
.option("password", "oxRDtsxrDhqkSRCJUpCaVBXaJscBDIjZ") \
.load()

display(df)

# %%
df.write.format("delta").saveAsTable("bronze_customers")
