# %% [markdown]
# 10.2.1 OPERATIONS

# %%
display(spark.read.format("delta").load("/Volumes/workspace/default/demo_volume/sales_delta"))

# %%
spark.sql("""
INSERT INTO delta.`/Volumes/workspace/default/demo_volume/sales_delta`
VALUES (111,'Anita','Mouse','Accessories',25,1,'Delhi')
""")

# %%
spark.sql("""
UPDATE delta.`/Volumes/workspace/default/demo_volume/sales_delta`
SET price = 850
WHERE city = 'Bangalore' AND product = 'Laptop'
""")

# %%
spark.sql("""
DELETE FROM delta.`/Volumes/workspace/default/demo_volume/sales_delta`
WHERE city = 'Pune'
""")

# %%
spark.sql("""
SELECT * 
FROM delta.`/Volumes/workspace/default/demo_volume/sales_delta`
WHERE city = 'Bangalore'
""").show()

# %% [markdown]
# Tune File Size

# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/workspace/default/demo_volume/sample_sales")

df.show()

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/default/demo_volume/sample_sales_delta")

# %%
df = spark.read.format("delta").load("/Volumes/workspace/default/demo_volume/sample_sales_delta")

print(df.rdd.getNumPartitions())

# %%
df = spark.read.format("delta").load("/Volumes/workspace/default/demo_volume/sample_sales_delta")

df_repartition = df.repartition(4)

# %%
spark.sql("""
OPTIMIZE delta.`/Volumes/workspace/default/demo_volume/sample_sales_selta'
""")
