# %%
dbutils.fs.ls("dbfs:/")

# %%
dbutils.fs.mounts()

# %%
dbutils.fs.ls("dbfs:/databricks-datasets/")

# %%
dbutils.fs.ls("dbfs:/FileStore/")

# %% [markdown]
# READING DATA

# %%
df = spark.read \
.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/workspace/default/demo_volume/sales.csv")

display(df)

# %%
df = spark.read.text("/Volumes/workspace/default/demo_volume/demo.txt")

display(df)
